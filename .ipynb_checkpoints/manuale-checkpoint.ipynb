# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
manuale= pd.read_csv('manuale.csv' ,sep=';' , thousands="." )
df=pd.DataFrame(manuale)
df
# Out:
#    Stagione               Calciatore     Squadra  Età  Partite Giocate  \
# 0   2024-25          Scott McTominay      Napoli   27               34
# 1   2024-25    Alessandro Buongiorno      Napoli   25               22
# 2   2024-25         Hakan Çalhanoğlu       Inter   30               29
# 3   2024-25             Armando Izzo       Monza   32               30
# 4   2024-25               Alex Meret      Napoli   27               34
# 5   2024-25          Mario Balotelli       Genoa   33                6
# 6   2024-25           Dušan Vlahović    Juventus   24               29
# 7   2024-25            Romelu Lukaku      Napoli   31               36
# 8   2024-25        Riccardo Orsolini     Bologna   27               30
# 9   2024-25  Pedro Rodríguez Ledesma       Lazio   37               30
# 10  2024-25   Vanja Milinković-Savić      Torino   27               37
# 11  2024-25        Giacomo Raspadori      Napoli   24               26
# 12  2024-25        Tijjani Reijnders       Milan   26               37
# 13  2024-25        José Manuel Reina        Como   41               12
# 14  2024-25      Francisco Conceição    Juventus   21               26
# 15  2024-25               Elif Elmas      Torino   24               13
# 16  2024-25               Moise Kean  Fiorentina   24               32
# 17  2024-25           Giovanni Leoni       Parma   17               17
# 18  2024-25              Yann Sommer       Inter   35               33
# 19  2024-25         Enrico Del Prato       Parma   24               34
# 20  2024-25                  Éderson    Atalanta   25               37
# 21  2024-25         Federico Dimarco       Inter   26               33
# 22  2024-25              Oumar Solet     Udinese   24               19
# 23  2024-25             Matìas Soulé        Roma   21               27
# 24  2024-25             Luca Ranieri  Fiorentina   25               36
#
#     Minuti Giocati  Reti  Assist  Reti Non Su Rigore  Rigori Tirati  \
# 0             2938    12       4                  12             12
# 1             1924     1       0                   1              1
# 2             1947     5       6                   2              2
# 3             2435     1       1                   1              1
# 4             3005     0       0                   0              0
# 5               62     0       0                   0              0
# 6             1784    10       4                   6              6
# 7             2843    14      10                  11             11
# 8             1878    15       4                  12             12
# 9             1102    10       1                   8              8
# 10            3330     0       0                   0              0
# 11            1103     6       1                   6              6
# 12            3128    10       4                  10             10
# 13            1034     0       0                   0              0
# 14            1340     3       3                   3              3
# 15            1021     4       0                   4              4
# 16            2704    19       3                  18             18
# 17            1199     1       0                   1              1
# 18            2970     0       0                   0              0
# 19            2947     4       0                   4              4
# 20            2881     4       1                   4              4
# 21            2177     4       7                   4              4
# 22            1672     1       2                   1              1
# 23            1781     5       5                   5              5
# 24            3071     1       3                   1              1
#
#     Ammonizioni  Espulsioni Ruolo?
# 0             3           0    Cen
# 1             2           0    Dif
# 2             5           0    Cen
# 3            12           0    Dif
# 4             0           0    Por
# 5             2           0    Att
# 6             3           0    Att
# 7             4           0    Att
# 8             2           0    Att
# 9             2           0    Att
# 10            3           0    Por
# 11            1           0    Att
# 12            2           1    Cen
# 13            0           1    Por
# 14            5           1    Cen
# 15            0           0    Cen
# 16            6           0    Att
# 17            3           1    Dif
# 18            0           0    Por
# 19            8           0    Dif
# 20            5           1    Cen
# 21            3           0    Dif
# 22            3           1    Dif
# 23            3           0    Cen
# 24            7           0    Dif

# %%
df.plot(kind="scatter",x="Partite Giocate",y="Minuti Giocati")
# Out:
# <Axes: xlabel='Partite Giocate', ylabel='Minuti Giocati'>

# %%
X = df[['Età', 'Partite Giocate','Reti']]  
y = df['Minuti Giocati']

# %%
X_b = np.c_[np.ones(X.shape[0]), X]  # shape (6, 3)

# Calcolo dei coefficienti beta = (XᵗX)^(-1) Xᵗy
beta = np.linalg.inv(X_b.T @ X_b) @ X_b.T @ y

# %%
y_pred = X_b @ beta  # previsioni su tutto il dataset
plt.scatter(y, y_pred, color='green', alpha=0.6)
plt.plot([y.min(), y.max()], [y.min(), y.max()], color='red', linestyle='--')
plt.xlabel("Valori reali")
plt.ylabel("Valori previsti")
plt.title("Confronto reale vs. previsto")
plt.grid(True)
plt.show()
